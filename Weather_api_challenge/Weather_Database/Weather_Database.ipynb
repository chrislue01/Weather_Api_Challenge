# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['vernon', 'gondanglegi', 'shelburne', 'port lincoln', 'kachikau', 'rikitea', 'cherskiy', 'grand river south east', 'ushuaia', 'georgetown'] Generate 725

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")

for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vernon
# Processing Record 2 of Set 1 | gondanglegi
# Processing Record 3 of Set 1 | shelburne
# Processing Record 4 of Set 1 | port lincoln
# Processing Record 5 of Set 1 | kachikau
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | lagoa
# Processing Record 12 of Set 1 | manjacaze
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | bilma
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | olafsvik
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | kidal
# Processing Record 21 of Set 1 | fianga
# City not found. Skipping...
# Processing Record 22 of Set 1 | yamada
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | ostersund
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | ugoofaaru
# Processing Record 29 of Set 1 | touros
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | afgoye
# City not found. Skipping...
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 1 | portland
# Processing Record 36 of Set 1 | presidencia roque saenz pena
# Processing Record 37 of Set 1 | waipawa
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | whitehaven
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | takapau
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | san cristobal
# Processing Record 46 of Set 1 | shingu
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | moose factory
# Processing Record 49 of Set 1 | kaitangata
# Processing Record 50 of Set 1 | ukiah
# Processing Record 1 of Set 2 | pokaran
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | urubicha
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | hamilton
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | mezen
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | yumen
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | lompoc
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | kirakira
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | xichang
# Processing Record 19 of Set 2 | rundu
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | acapulco
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | husavik
# Processing Record 24 of Set 2 | cairo
# Processing Record 25 of Set 2 | alvand
# Processing Record 26 of Set 2 | abu dhabi
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | belaya gora
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | juterbog
# Processing Record 31 of Set 2 | sorland
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | plettenberg bay
# Processing Record 35 of Set 2 | binzhou
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | fare
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | zvishavane
# Processing Record 41 of Set 2 | yar-sale
# Processing Record 42 of Set 2 | goba
# Processing Record 43 of Set 2 | safaqis
# City not found. Skipping...
# Processing Record 44 of Set 2 | redmond
# Processing Record 45 of Set 2 | shar
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | pemangkat
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | rila
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | nanortalik
# Processing Record 2 of Set 3 | palmerston
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | ayagoz
# Processing Record 6 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 3 | inhambane
# Processing Record 8 of Set 3 | koslan
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | belousovka
# Processing Record 12 of Set 3 | san ramon de la nueva oran
# Processing Record 13 of Set 3 | port blair
# Processing Record 14 of Set 3 | talcahuano
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 3 | grand gaube
# Processing Record 18 of Set 3 | new norfolk
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | khatanga
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | buraydah
# Processing Record 24 of Set 3 | kapaa
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | cairns
# Processing Record 30 of Set 3 | russell
# Processing Record 31 of Set 3 | puro
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | saint-augustin
# Processing Record 35 of Set 3 | guekedou
# City not found. Skipping...
# Processing Record 36 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 3 | linhares
# Processing Record 38 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 3 | vestmannaeyjar
# Processing Record 40 of Set 3 | soyo
# Processing Record 41 of Set 3 | sinegorye
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | pitimbu
# Processing Record 48 of Set 3 | constitucion
# Processing Record 49 of Set 3 | beira
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 4 | narsaq
# Processing Record 3 of Set 4 | esperance
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 4 | leshan
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | brae
# Processing Record 10 of Set 4 | jamestown
# Processing Record 11 of Set 4 | guerrero negro
# Processing Record 12 of Set 4 | sechura
# Processing Record 13 of Set 4 | mount isa
# Processing Record 14 of Set 4 | terrak
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | chokurdakh
# Processing Record 17 of Set 4 | altay
# Processing Record 18 of Set 4 | gizo
# Processing Record 19 of Set 4 | kokkola
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 4 | polson
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | kurya
# Processing Record 25 of Set 4 | najran
# Processing Record 26 of Set 4 | urengoy
# Processing Record 27 of Set 4 | olinda
# Processing Record 28 of Set 4 | miles city
# Processing Record 29 of Set 4 | saint-jovite
# Processing Record 30 of Set 4 | beloha
# Processing Record 31 of Set 4 | arakhova
# City not found. Skipping...
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | ocala
# Processing Record 34 of Set 4 | helong
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | samfya
# Processing Record 37 of Set 4 | moree
# Processing Record 38 of Set 4 | kalmunai
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | requena
# Processing Record 42 of Set 4 | port elizabeth
# Processing Record 43 of Set 4 | giyani
# Processing Record 44 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 4 | omboue
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | nemuro
# Processing Record 48 of Set 4 | bambous virieux
# Processing Record 49 of Set 4 | shumskiy
# Processing Record 50 of Set 4 | carballo
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | vostok
# Processing Record 3 of Set 5 | qaanaaq
# Processing Record 4 of Set 5 | hasaki
# Processing Record 5 of Set 5 | shibetsu
# Processing Record 6 of Set 5 | pedasi
# Processing Record 7 of Set 5 | trelew
# Processing Record 8 of Set 5 | harrow
# Processing Record 9 of Set 5 | rexburg
# Processing Record 10 of Set 5 | alofi
# Processing Record 11 of Set 5 | varnavino
# Processing Record 12 of Set 5 | port alfred
# Processing Record 13 of Set 5 | nome
# Processing Record 14 of Set 5 | sitka
# Processing Record 15 of Set 5 | taltal
# Processing Record 16 of Set 5 | airai
# Processing Record 17 of Set 5 | saldanha
# Processing Record 18 of Set 5 | laguna
# Processing Record 19 of Set 5 | sabzevar
# Processing Record 20 of Set 5 | albania
# Processing Record 21 of Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 22 of Set 5 | kralendijk
# Processing Record 23 of Set 5 | saint-philippe
# Processing Record 24 of Set 5 | khotyn
# Processing Record 25 of Set 5 | nyurba
# Processing Record 26 of Set 5 | vaitape
# Processing Record 27 of Set 5 | bukama
# Processing Record 28 of Set 5 | amapa
# Processing Record 29 of Set 5 | palmer
# Processing Record 30 of Set 5 | carutapera
# Processing Record 31 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 5 | mullovka
# Processing Record 33 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | praia da vitoria
# Processing Record 36 of Set 5 | charlestown
# Processing Record 37 of Set 5 | rawson
# Processing Record 38 of Set 5 | bushehr
# Processing Record 39 of Set 5 | wanning
# Processing Record 40 of Set 5 | acacoyagua
# Processing Record 41 of Set 5 | ancud
# Processing Record 42 of Set 5 | copiapo
# Processing Record 43 of Set 5 | visnes
# Processing Record 44 of Set 5 | broome
# Processing Record 45 of Set 5 | houma
# Processing Record 46 of Set 5 | chenghai
# Processing Record 47 of Set 5 | tabas
# Processing Record 48 of Set 5 | bolama
# Processing Record 49 of Set 5 | port hardy
# Processing Record 50 of Set 5 | imbituba
# Processing Record 1 of Set 6 | westport
# Processing Record 2 of Set 6 | sao jose da coroa grande
# Processing Record 3 of Set 6 | yasnyy
# Processing Record 4 of Set 6 | marsh harbour
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | sovetskaya gavan
# Processing Record 7 of Set 6 | fuyang
# Processing Record 8 of Set 6 | the valley
# Processing Record 9 of Set 6 | shenjiamen
# Processing Record 10 of Set 6 | kununurra
# Processing Record 11 of Set 6 | jamui
# Processing Record 12 of Set 6 | half moon bay
# Processing Record 13 of Set 6 | rawlins
# Processing Record 14 of Set 6 | venezuela
# Processing Record 15 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 6 | dhidhdhoo
# Processing Record 17 of Set 6 | tanete
# Processing Record 18 of Set 6 | mandalgovi
# Processing Record 19 of Set 6 | auki
# Processing Record 20 of Set 6 | grand forks
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | gawler
# Processing Record 23 of Set 6 | fortuna foothills
# Processing Record 24 of Set 6 | aklavik
# Processing Record 25 of Set 6 | coahuayana
# Processing Record 26 of Set 6 | sampit
# Processing Record 27 of Set 6 | itumba
# Processing Record 28 of Set 6 | victoria
# Processing Record 29 of Set 6 | revda
# Processing Record 30 of Set 6 | preobrazheniye
# Processing Record 31 of Set 6 | lata
# Processing Record 32 of Set 6 | maldonado
# Processing Record 33 of Set 6 | boende
# Processing Record 34 of Set 6 | boyolangu
# Processing Record 35 of Set 6 | belmonte
# Processing Record 36 of Set 6 | frunze
# Processing Record 37 of Set 6 | oranjemund
# Processing Record 38 of Set 6 | nhulunbuy
# Processing Record 39 of Set 6 | staraya poltavka
# Processing Record 40 of Set 6 | nalut
# Processing Record 41 of Set 6 | osa
# Processing Record 42 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 6 | san onofre
# Processing Record 44 of Set 6 | rovaniemi
# Processing Record 45 of Set 6 | hofn
# Processing Record 46 of Set 6 | shitanjing
# Processing Record 47 of Set 6 | saint-francois
# Processing Record 48 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 6 | flin flon
# Processing Record 50 of Set 6 | yuksekova
# Processing Record 1 of Set 7 | padang
# Processing Record 2 of Set 7 | huamuxtitlan
# Processing Record 3 of Set 7 | bambanglipuro
# Processing Record 4 of Set 7 | fairbanks
# Processing Record 5 of Set 7 | turukhansk
# Processing Record 6 of Set 7 | lerwick
# Processing Record 7 of Set 7 | kushmurun
# Processing Record 8 of Set 7 | itarema
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | nayudupeta
# Processing Record 11 of Set 7 | sosnovskoye
# Processing Record 12 of Set 7 | daru
# Processing Record 13 of Set 7 | nizhnevartovsk
# Processing Record 14 of Set 7 | kindersley
# Processing Record 15 of Set 7 | mar del plata
# Processing Record 16 of Set 7 | porangatu
# Processing Record 17 of Set 7 | henties bay
# Processing Record 18 of Set 7 | tornio
# Processing Record 19 of Set 7 | laguna de perlas
# Processing Record 20 of Set 7 | sola
# Processing Record 21 of Set 7 | victor harbor
# Processing Record 22 of Set 7 | bayir
# Processing Record 23 of Set 7 | avera
# Processing Record 24 of Set 7 | san quintin
# Processing Record 25 of Set 7 | yulara
# Processing Record 26 of Set 7 | aktash
# Processing Record 27 of Set 7 | siverskiy
# Processing Record 28 of Set 7 | salalah
# Processing Record 29 of Set 7 | nishihara
# Processing Record 30 of Set 7 | fountain
# Processing Record 31 of Set 7 | pacific grove
# Processing Record 32 of Set 7 | santa maria
# Processing Record 33 of Set 7 | tianpeng
# Processing Record 34 of Set 7 | port macquarie
# Processing Record 35 of Set 7 | livingstonia
# Processing Record 36 of Set 7 | yurimaguas
# Processing Record 37 of Set 7 | defiance
# Processing Record 38 of Set 7 | okhotsk
# Processing Record 39 of Set 7 | new waterford
# Processing Record 40 of Set 7 | balabac
# Processing Record 41 of Set 7 | saint-louis
# Processing Record 42 of Set 7 | umm lajj
# Processing Record 43 of Set 7 | camana
# Processing Record 44 of Set 7 | sao joao da barra
# Processing Record 45 of Set 7 | turayf
# Processing Record 46 of Set 7 | itatskiy
# Processing Record 47 of Set 7 | necochea
# Processing Record 48 of Set 7 | zhigansk
# Processing Record 49 of Set 7 | oktyabrskoye
# Processing Record 50 of Set 7 | camacha
# Processing Record 1 of Set 8 | faya
# Processing Record 2 of Set 8 | umm bab
# Processing Record 3 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 8 | pucallpa
# Processing Record 5 of Set 8 | arkhipo-osipovka
# Processing Record 6 of Set 8 | araguaina
# Processing Record 7 of Set 8 | atar
# Processing Record 8 of Set 8 | medvedka
# Processing Record 9 of Set 8 | maceio
# Processing Record 10 of Set 8 | kaeo
# Processing Record 11 of Set 8 | zalantun
# Processing Record 12 of Set 8 | aswan
# Processing Record 13 of Set 8 | vanimo
# Processing Record 14 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 8 | pimentel
# Processing Record 16 of Set 8 | provideniya
# Processing Record 17 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 18 of Set 8 | jundiai
# Processing Record 19 of Set 8 | nizwa
# Processing Record 20 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 8 | gat
# Processing Record 22 of Set 8 | dotnuva
# Processing Record 23 of Set 8 | whitehorse
# Processing Record 24 of Set 8 | sangar
# Processing Record 25 of Set 8 | goure
# Processing Record 26 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 27 of Set 8 | namibe
# Processing Record 28 of Set 8 | yaan
# Processing Record 29 of Set 8 | bay-khaak
# Processing Record 30 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 31 of Set 8 | trenggalek
# Processing Record 32 of Set 8 | turgoyak
# Processing Record 33 of Set 8 | aktau
# Processing Record 34 of Set 8 | nsanje
# Processing Record 35 of Set 8 | vuktyl
# Processing Record 36 of Set 8 | rovnoye
# Processing Record 37 of Set 8 | phan thiet
# Processing Record 38 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 8 | itumbiara
# Processing Record 40 of Set 8 | schoningen
# Processing Record 41 of Set 8 | san rafael
# Processing Record 42 of Set 8 | bengkalis
# City not found. Skipping...
# Processing Record 43 of Set 8 | adrar
# Processing Record 44 of Set 8 | ucluelet
# Processing Record 45 of Set 8 | nioro
# Processing Record 46 of Set 8 | rheinbach
# Processing Record 47 of Set 8 | prachin buri
# Processing Record 48 of Set 8 | chernyshevskiy
# Processing Record 49 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 8 | tura
# Processing Record 1 of Set 9 | mehamn
# Processing Record 2 of Set 9 | paracuru
# Processing Record 3 of Set 9 | cenotillo
# Processing Record 4 of Set 9 | namatanai
# Processing Record 5 of Set 9 | outjo
# Processing Record 6 of Set 9 | chabahar
# Processing Record 7 of Set 9 | camabatela
# Processing Record 8 of Set 9 | conceicao da barra
# Processing Record 9 of Set 9 | awbari
# Processing Record 10 of Set 9 | sur
# Processing Record 11 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 9 | almaznyy
# Processing Record 13 of Set 9 | krasnoselkup
# Processing Record 14 of Set 9 | alta floresta
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | mnogovershinnyy
# Processing Record 17 of Set 9 | suntar
# Processing Record 18 of Set 9 | salina
# Processing Record 19 of Set 9 | santa luzia
# Processing Record 20 of Set 9 | leningradskiy
# Processing Record 21 of Set 9 | kisangani
# Processing Record 22 of Set 9 | hailar
# Processing Record 23 of Set 9 | verkhnyaya inta
# Processing Record 24 of Set 9 | kavaratti
# Processing Record 25 of Set 9 | codrington
# Processing Record 26 of Set 9 | bandarbeyla
# Processing Record 27 of Set 9 | christchurch
# Processing Record 28 of Set 9 | khandyga
# Processing Record 29 of Set 9 | hearst
# Processing Record 30 of Set 9 | comodoro rivadavia
# Processing Record 31 of Set 9 | raga
# Processing Record 32 of Set 9 | mozarlandia
# Processing Record 33 of Set 9 | luanda
# Processing Record 34 of Set 9 | champerico
# Processing Record 35 of Set 9 | alice springs
# Processing Record 36 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 9 | rudbar
# Processing Record 38 of Set 9 | mushie
# Processing Record 39 of Set 9 | manyana
# Processing Record 40 of Set 9 | brasilia
# Processing Record 41 of Set 9 | flinders
# Processing Record 42 of Set 9 | rio grande
# Processing Record 43 of Set 9 | kutum
# Processing Record 44 of Set 9 | san-pedro
# Processing Record 45 of Set 9 | samarinda
# Processing Record 46 of Set 9 | catuday
# Processing Record 47 of Set 9 | kilindoni
# Processing Record 48 of Set 9 | bonavista
# Processing Record 49 of Set 9 | lazaro cardenas
# Processing Record 50 of Set 9 | monte patria
# Processing Record 1 of Set 10 | loukhi
# Processing Record 2 of Set 10 | zhangye
# Processing Record 3 of Set 10 | lunenburg
# Processing Record 4 of Set 10 | teahupoo
# Processing Record 5 of Set 10 | peniche
# Processing Record 6 of Set 10 | kargasok
# Processing Record 7 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 10 | praia
# Processing Record 9 of Set 10 | tevriz
# Processing Record 10 of Set 10 | coihaique
# Processing Record 11 of Set 10 | northam
# Processing Record 12 of Set 10 | talnakh
# Processing Record 13 of Set 10 | vardo
# Processing Record 14 of Set 10 | sergeyevka
# Processing Record 15 of Set 10 | atherton
# Processing Record 16 of Set 10 | veraval
# Processing Record 17 of Set 10 | altamira
# Processing Record 18 of Set 10 | svetlyy
# Processing Record 19 of Set 10 | sunndalsora
# Processing Record 20 of Set 10 | meadow lake
# Processing Record 21 of Set 10 | wadi musa
# Processing Record 22 of Set 10 | warrington
# Processing Record 23 of Set 10 | neuquen
# Processing Record 24 of Set 10 | mayumba
# Processing Record 25 of Set 10 | kabwe
# Processing Record 26 of Set 10 | mundo nuevo
# Processing Record 27 of Set 10 | kpandae
# Processing Record 28 of Set 10 | norwalk
# Processing Record 29 of Set 10 | talaja
# Processing Record 30 of Set 10 | kavieng
# Processing Record 31 of Set 10 | kijang
# Processing Record 32 of Set 10 | carcassonne
# Processing Record 33 of Set 10 | ardino
# Processing Record 34 of Set 10 | omsukchan
# Processing Record 35 of Set 10 | brigantine
# Processing Record 36 of Set 10 | morondava
# Processing Record 37 of Set 10 | caravelas
# Processing Record 38 of Set 10 | asmara
# Processing Record 39 of Set 10 | bria
# Processing Record 40 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 10 | apiai
# Processing Record 42 of Set 10 | pringsewu
# Processing Record 43 of Set 10 | ganzhou
# Processing Record 44 of Set 10 | puerto madryn
# Processing Record 45 of Set 10 | salinas
# Processing Record 46 of Set 10 | edgewater
# Processing Record 47 of Set 10 | jodhpur
# Processing Record 48 of Set 10 | tondano
# Processing Record 49 of Set 10 | sydney
# Processing Record 50 of Set 10 | takoradi
# Processing Record 1 of Set 11 | kirksville
# Processing Record 2 of Set 11 | ringebu
# Processing Record 3 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 4 of Set 11 | ustrzyki dolne
# Processing Record 5 of Set 11 | anadyr
# Processing Record 6 of Set 11 | qaqortoq
# Processing Record 7 of Set 11 | igurusi
# Processing Record 8 of Set 11 | qujing
# Processing Record 9 of Set 11 | belle glade
# Processing Record 10 of Set 11 | diffa
# Processing Record 11 of Set 11 | kamenka
# Processing Record 12 of Set 11 | finnsnes
# Processing Record 13 of Set 11 | canaries
# Processing Record 14 of Set 11 | hirara
# Processing Record 15 of Set 11 | piliscsaba
# Processing Record 16 of Set 11 | mosetse
# Processing Record 17 of Set 11 | tyukhtet
# Processing Record 18 of Set 11 | mincivan
# Processing Record 19 of Set 11 | druzhba
# Processing Record 20 of Set 11 | ust-kuyga
# Processing Record 21 of Set 11 | jacobina
# Processing Record 22 of Set 11 | porto-vecchio
# Processing Record 23 of Set 11 | paamiut
# Processing Record 24 of Set 11 | yarada
# Processing Record 25 of Set 11 | panguna
# Processing Record 26 of Set 11 | margate
# Processing Record 27 of Set 11 | nampula
# Processing Record 28 of Set 11 | niquero
# Processing Record 29 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 11 | garden city
# Processing Record 31 of Set 11 | rocha
# Processing Record 32 of Set 11 | roebourne
# Processing Record 33 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 11 | acarau
# Processing Record 35 of Set 11 | taoudenni
# Processing Record 36 of Set 11 | amarillo
# Processing Record 37 of Set 11 | xifeng
# Processing Record 38 of Set 11 | banjar
# Processing Record 39 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 11 | princeton
# Processing Record 41 of Set 11 | mednogorsk
# Processing Record 42 of Set 11 | ambon
# Processing Record 43 of Set 11 | walvis bay
# Processing Record 44 of Set 11 | aksay
# Processing Record 45 of Set 11 | urman
# Processing Record 46 of Set 11 | vanavara
# Processing Record 47 of Set 11 | toda raisingh
# Processing Record 48 of Set 11 | bend
# Processing Record 49 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 11 | dingle
# Processing Record 1 of Set 12 | mahanoro
# Processing Record 2 of Set 12 | college
# Processing Record 3 of Set 12 | karpathos
# Processing Record 4 of Set 12 | sangmelima
# Processing Record 5 of Set 12 | khromtau
# Processing Record 6 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | keti bandar
# Processing Record 8 of Set 12 | horki
# Processing Record 9 of Set 12 | mizan teferi
# Processing Record 10 of Set 12 | murray bridge
# Processing Record 11 of Set 12 | west bay
# Processing Record 12 of Set 12 | muzhi
# Processing Record 13 of Set 12 | bocas del toro
# Processing Record 14 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 12 | cockburn town
# Processing Record 16 of Set 12 | gisborne
# Processing Record 17 of Set 12 | korcula
# Processing Record 18 of Set 12 | molokovo
# Processing Record 19 of Set 12 | port-cartier
# Processing Record 20 of Set 12 | labuhan
# Processing Record 21 of Set 12 | johor bahru
# Processing Record 22 of Set 12 | pochutla
# Processing Record 23 of Set 12 | idil
# Processing Record 24 of Set 12 | valley city
# Processing Record 25 of Set 12 | nuevo progreso
# Processing Record 26 of Set 12 | port keats
# Processing Record 27 of Set 12 | bud
# Processing Record 28 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 12 | marzuq
# Processing Record 30 of Set 12 | isla aguada
# Processing Record 31 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 12 | nouadhibou
# Processing Record 33 of Set 12 | magaria
# Processing Record 34 of Set 12 | vao
# Processing Record 35 of Set 12 | iracoubo
# Processing Record 36 of Set 12 | jian
# Processing Record 37 of Set 12 | rio gallegos
# Processing Record 38 of Set 12 | haines junction
# Processing Record 39 of Set 12 | ladybrand
# Processing Record 40 of Set 12 | srednekolymsk
# Processing Record 41 of Set 12 | diego de almagro
# Processing Record 42 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 12 | guanica
# Processing Record 44 of Set 12 | aykhal
# Processing Record 45 of Set 12 | muli
# Processing Record 46 of Set 12 | ocos
# Processing Record 47 of Set 12 | utmanzai
# Processing Record 48 of Set 12 | ust-kulom
# Processing Record 49 of Set 12 | gander
# Processing Record 50 of Set 12 | mandurah
# Processing Record 1 of Set 13 | wajima
# Processing Record 2 of Set 13 | meulaboh
# Processing Record 3 of Set 13 | barcelos
# Processing Record 4 of Set 13 | kudahuvadhoo
# Processing Record 5 of Set 13 | killybegs
# Processing Record 6 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 13 | torrington
# Processing Record 8 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 13 | bosaso
# Processing Record 10 of Set 13 | winneba
# Processing Record 11 of Set 13 | quatre cocos
# Processing Record 12 of Set 13 | balsas
# Processing Record 13 of Set 13 | uchkent
# Processing Record 14 of Set 13 | mayor pablo lagerenza
# Processing Record 15 of Set 13 | salta
# Processing Record 16 of Set 13 | san patricio
# Processing Record 17 of Set 13 | phatthalung
# Processing Record 18 of Set 13 | santarem
# Processing Record 19 of Set 13 | gamba
# Processing Record 20 of Set 13 | igrim
# Processing Record 21 of Set 13 | conde
# Processing Record 22 of Set 13 | arlit
# Processing Record 23 of Set 13 | marivan
# Processing Record 24 of Set 13 | shimoda
# Processing Record 25 of Set 13 | santa comba
# Processing Record 26 of Set 13 | roswell
# Processing Record 27 of Set 13 | vytegra
# Processing Record 28 of Set 13 | bogorodskoye
# Processing Record 29 of Set 13 | finschhafen
# Processing Record 30 of Set 13 | rabo de peixe
# Processing Record 31 of Set 13 | lavrentiya
# Processing Record 32 of Set 13 | coquimbo
# Processing Record 33 of Set 13 | constantine
# Processing Record 34 of Set 13 | noumea
# Processing Record 35 of Set 13 | changli
# Processing Record 36 of Set 13 | liverpool
# Processing Record 37 of Set 13 | moindou
# Processing Record 38 of Set 13 | selaphum
# Processing Record 39 of Set 13 | trincomalee
# Processing Record 40 of Set 13 | chinhoyi
# Processing Record 41 of Set 13 | kostrzyn
# Processing Record 42 of Set 13 | indiaroba
# Processing Record 43 of Set 13 | callaguip
# Processing Record 44 of Set 13 | marystown
# Processing Record 45 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 13 | sobolevo
# Processing Record 47 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 13 | antofagasta
# Processing Record 49 of Set 13 | pampa
# Processing Record 50 of Set 13 | maniitsoq
# Processing Record 1 of Set 14 | muniz freire
# Processing Record 2 of Set 14 | paraiso
# Processing Record 3 of Set 14 | eyl
# Processing Record 4 of Set 14 | langham
# Processing Record 5 of Set 14 | oron
# Processing Record 6 of Set 14 | manjeshwar
# Processing Record 7 of Set 14 | elbistan
# Processing Record 8 of Set 14 | maroua
# Processing Record 9 of Set 14 | saint-joseph
# Processing Record 10 of Set 14 | zvenigorod
# Processing Record 11 of Set 14 | terme
# Processing Record 12 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 13 of Set 14 | clarence town
# Processing Record 14 of Set 14 | balaipungut
# Processing Record 15 of Set 14 | ambilobe
# Processing Record 16 of Set 14 | bilibino
# Processing Record 17 of Set 14 | hefei
# Processing Record 18 of Set 14 | mulki
# Processing Record 19 of Set 14 | bam
# Processing Record 20 of Set 14 | komsomolskiy
# Processing Record 21 of Set 14 | chimoio
# Processing Record 22 of Set 14 | san policarpo
# Processing Record 23 of Set 14 | strezhevoy
# Processing Record 24 of Set 14 | debre tabor
# Processing Record 25 of Set 14 | hailey
# Processing Record 26 of Set 14 | hayesville
# Processing Record 27 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 14 | luderitz
# Processing Record 29 of Set 14 | saint-jean-de-luz
# Processing Record 30 of Set 14 | beringovskiy
# Processing Record 31 of Set 14 | ahipara
# Processing Record 32 of Set 14 | tevaitoa
# Processing Record 33 of Set 14 | hervey bay
# Processing Record 34 of Set 14 | shonguy
# Processing Record 35 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 14 | cochabamba
# Processing Record 37 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 38 of Set 14 | aloleng
# Processing Record 39 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 14 | ubinskoye
# Processing Record 41 of Set 14 | mumford
# Processing Record 42 of Set 14 | iwanai
# Processing Record 43 of Set 14 | aboisso
# Processing Record 44 of Set 14 | viedma
# Processing Record 45 of Set 14 | ozernovskiy
# Processing Record 46 of Set 14 | kinkala
# Processing Record 47 of Set 14 | marrakesh
# Processing Record 48 of Set 14 | dongsheng
# Processing Record 49 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 14 | yuzhno-kurilsk
# Processing Record 1 of Set 15 | akhtubinsk
# Processing Record 2 of Set 15 | novikovo
# Processing Record 3 of Set 15 | vagay
# Processing Record 4 of Set 15 | buluang
# Processing Record 5 of Set 15 | phuket
# Processing Record 6 of Set 15 | sitia
# Processing Record 7 of Set 15 | sabang
# Processing Record 8 of Set 15 | xiongzhou
# Processing Record 9 of Set 15 | guarapari
# Processing Record 10 of Set 15 | moron
# Processing Record 11 of Set 15 | salinopolis
# Processing Record 12 of Set 15 | newport
# Processing Record 13 of Set 15 | apatou
# Processing Record 14 of Set 15 | gap
# Processing Record 15 of Set 15 | ibra
# Processing Record 16 of Set 15 | pontianak
# Processing Record 17 of Set 15 | stutterheim
# Processing Record 18 of Set 15 | iroquois falls
# Processing Record 19 of Set 15 | okrika
# Processing Record 20 of Set 15 | maraa
# Processing Record 21 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 22 of Set 15 | ostrovnoy
# Processing Record 23 of Set 15 | madison
# Processing Record 24 of Set 15 | smolenka
# Processing Record 25 of Set 15 | nuuk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 663

# %%
# Create the output file (CSV).
output_data_file = "untitled folder 1/weather_api_challenge/challenge_data.csv"
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv('challenge_city_data.csv',index_label='City_ID')

# %%
challenge_city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0        vernon      CA  2022-05-27 04:14:07  50.2581 -119.2691     65.23
# 1   gondanglegi      ID  2022-05-27 04:14:07  -7.7479  112.0132     84.88
# 2     shelburne      CA  2022-05-27 04:11:47  44.0787  -80.2041     65.75
# 3  port lincoln      AU  2022-05-27 04:13:30 -34.7333  135.8667     60.37
# 4       rikitea      PF  2022-05-27 04:14:08 -23.1203 -134.9692     77.00
# 5      cherskiy      RU  2022-05-27 04:14:08  68.7500  161.3000     41.40
# 6       ushuaia      AR  2022-05-27 04:11:23 -54.8000  -68.3000     33.46
# 7    georgetown      MY  2022-05-27 04:14:09   5.4112  100.3354     89.53
# 8         lagoa      PT  2022-05-27 04:14:09  39.0500  -27.9833     62.31
# 9     manjacaze      MZ  2022-05-27 04:09:21 -24.7117   33.8828     64.11
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        58         100        5.39     overcast clouds
# 1        66          96        2.30     overcast clouds
# 2        86         100       12.71     overcast clouds
# 3        53          67       12.59       broken clouds
# 4        76          24       14.00          light rain
# 5        49          86       20.71     overcast clouds
# 6        86         100       26.46          light snow
# 7        66          20        6.91          few clouds
# 8        85          70       20.38       broken clouds
# 9        96           7        2.01           clear sky
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                       0.0                         0
# 1                       0.0                         0
# 2                       0.0                         0
# 3                       0.0                         0
# 4                       0.0                         0
# 5                       0.0                         0
# 6                       0.0                         0
# 7                       0.0                         0
# 8                       0.0                         0
# 9                       0.0                         0

# %%
# Create the output file (CSV).
output_data_file = "untitled folder 1/weather_api_challenge/WeatherPy_Database.csv"
#Save the new DataFrame as a CSV file
challenge_city_data_df = challenge_city_data_df.head(10)
challenge_city_data_df.to_csv('WeatherPy_Database.csv',index_label='City_ID')
